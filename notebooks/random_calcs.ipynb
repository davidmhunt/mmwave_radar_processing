# %%
import numpy as np
from matplotlib import pyplot as plt
thetas = np.deg2rad(np.linspace(
    start=5,
    stop=30,
    num=90
))

v = 1.0

v_d = v * np.cos(thetas) - v * np.cos(thetas - np.deg2rad(5))

plt.plot(np.rad2deg(thetas),v_d)
plt.grid()
